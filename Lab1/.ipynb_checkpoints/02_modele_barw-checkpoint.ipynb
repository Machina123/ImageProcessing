# %%
from skimage import data

im = data.astronaut()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.imshow(im, cmap="gray")
plt.axis('off')
plt.show()

# %%
print(im.shape, im.dtype)
# Out:
# (512, 512, 3) uint8

# %%
print(im[:5,:5])
# Out:
# [[[154 147 151]
#   [109 103 124]
#   [ 63  58 102]
#   [ 54  51  98]
#   [ 76  76 106]]
#
#  [[177 171 171]
#   [144 141 143]
#   [113 114 124]
#   [106 107 120]
#   [128 128 131]]
#
#  [[201 194 193]
#   [182 178 175]
#   [168 165 164]
#   [159 157 157]
#   [167 165 161]]
#
#  [[220 213 210]
#   [214 206 206]
#   [202 198 196]
#   [197 191 193]
#   [200 194 196]]
#
#  [[232 223 223]
#   [226 220 215]
#   [221 215 210]
#   [215 210 206]
#   [221 211 213]]]

# %%
from skimage.color import convert_colorspace, rgb2lab, rgb2hsv, rgb2gray

imHSV = rgb2hsv(im)
# Out:
# /anaconda3/envs/py36/lib/python3.6/site-packages/skimage/color/colorconv.py:275: RuntimeWarning: divide by zero encountered in true_divide
#   out[idx, 0] = (arr[idx, 1] - arr[idx, 2]) / delta[idx]
# /anaconda3/envs/py36/lib/python3.6/site-packages/skimage/color/colorconv.py:279: RuntimeWarning: divide by zero encountered in true_divide
#   out[idx, 0] = 2. + (arr[idx, 2] - arr[idx, 0]) / delta[idx]
# /anaconda3/envs/py36/lib/python3.6/site-packages/skimage/color/colorconv.py:283: RuntimeWarning: divide by zero encountered in true_divide
#   out[idx, 0] = 4. + (arr[idx, 0] - arr[idx, 1]) / delta[idx]

# %%
print(imHSV.shape, imHSV.dtype)
# Out:
# (512, 512, 3) float64

# %%
print(imHSV[:3,:3])
# Out:
# [[[0.9047619  0.04545455 0.60392157]
#   [0.71428571 0.16935484 0.48627451]
#   [0.68560606 0.43137255 0.4       ]]
#
#  [[0.         0.03389831 0.69411765]
#   [0.88888889 0.02083333 0.56470588]
#   [0.65151515 0.08870968 0.48627451]]
#
#  [[0.02083333 0.039801   0.78823529]
#   [0.07142857 0.03846154 0.71372549]
#   [0.04166667 0.02380952 0.65882353]]]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.imshow(imHSV, cmap="gray")
plt.axis('off')
plt.show()

# %%
imLab = rgb2lab(im)

print(imLab.shape, imLab.dtype)
# Out:
# (512, 512, 3) float64

# %%
print(imLab[:3, :3])
# Out:
# [[[ 61.63005128   3.32356587  -1.18519659]
#   [ 44.81085424   6.84303637 -10.82581523]
#   [ 26.85396102  13.93161885 -25.16330882]]
#
#  [[ 70.46461472   2.13767325   0.76550025]
#   [ 58.93939541   1.49051099  -0.66732405]
#   [ 48.26060107   1.73769462  -5.62832699]]
#
#  [[ 78.95575225   2.2586027    1.37416691]
#   [ 72.81362004   0.8646019    2.03421156]
#   [ 67.95833308   0.88583093   0.90058539]]]

# %%
print(imLab.min())
# Out:
# -51.966470632538496

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.imshow(imLab, cmap="gray")
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
